# %%
import src.dataset as dataset
# Import the data
df = dataset.load_voice_dataset()

# %%
# The data before normalization
df.head(5)
# Out:
#    Unnamed: 0            name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  \
# 0           0  phon_R01_S01_1      119.992       157.302        74.997
# 1           1  phon_R01_S01_2      122.400       148.650       113.819
# 2           2  phon_R01_S01_3      116.682       131.111       111.555
# 3           3  phon_R01_S01_4      116.676       137.871       111.366
# 4           4  phon_R01_S01_5      116.014       141.781       110.655
#
#    MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  ...  \
# 0         0.00784           0.00007   0.00370   0.00554     0.01109  ...
# 1         0.00968           0.00008   0.00465   0.00696     0.01394  ...
# 2         0.01050           0.00009   0.00544   0.00781     0.01633  ...
# 3         0.00997           0.00009   0.00502   0.00698     0.01505  ...
# 4         0.01284           0.00011   0.00655   0.00908     0.01966  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# The data after normalization. 
# The order of some of the attributes change due to the removal and reconcatination that takes place to only normalize the values we want
df_normalized = dataset.normalize_dataset(df)
df_normalized.head(5)
# Out:
#    Unnamed: 0            name  status  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  \
# 0           0  phon_R01_S01_1       1     0.184308      0.112592
# 1           1  phon_R01_S01_2       1     0.198327      0.094930
# 2           2  phon_R01_S01_3       1     0.165039      0.059128
# 3           3  phon_R01_S01_4       1     0.165004      0.072927
# 4           4  phon_R01_S01_5       1     0.161150      0.080909
#
#    MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  ...  \
# 0      0.054815        0.195680          0.249012  0.145472  0.247588  ...
# 1      0.278323        0.254130          0.288538  0.191233  0.323687  ...
# 2      0.265288        0.280178          0.328063  0.229287  0.369239  ...
# 3      0.264200        0.263342          0.328063  0.209056  0.324759  ...
# 4      0.260107        0.354511          0.407115  0.282755  0.437299  ...
#
#    MDVP:APQ  Shimmer:DDA       NHR       HNR      RPDE       DFA   spread1  \
# ...

# %%
# Test cases
print("Size is retained: ", df.size == df_normalized.size)

# Export both dataframes to .csv files
df.to_csv("./DataFrames/df.csv")
df_normalized.to_csv("./DataFrames/df_normalized.csv")
# Out:
# Size is retained:  True
